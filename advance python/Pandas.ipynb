# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
l=[10,20,30,40]
s=pd.Series(l)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
l=[10,20,30,40]
s=pd.Series(l,index=["a","b","c","d"], name="python",dtype="float")
print(s)
# Out:
# a    10.0
# b    20.0
# c    30.0
# d    40.0
# Name: python, dtype: float64

# %%
d={"A":[10,20,30,40,50],"B":[100,200,300,400]}
s1=pd.Series(d)
print(s1)
print(type(s1))
print(s1["A"])
# Out:
# A    [10, 20, 30, 40, 50]
# B    [100, 200, 300, 400]
# dtype: object
# <class 'pandas.core.series.Series'>
# [10, 20, 30, 40, 50]

# %%
s=pd.Series(12,index=[1,2,3,4,5,6,7])
print(s)
# Out:
# 1    12
# 2    12
# 3    12
# 4    12
# 5    12
# 6    12
# 7    12
# dtype: int64

# %%
s1=pd.Series(12,index=[1,2,3,4,5,6,7])
s2=pd.Series(12,index=[1,2,3,4])
s3=s1+s2
print(s3)
# Out:
# 1    24.0
# 2    24.0
# 3    24.0
# 4    24.0
# 5     NaN
# 6     NaN
# 7     NaN
# dtype: float64

# %%
dic={"A":[10,20,30,40,50],"B":[100,200,300,400,500]}
df=pd.DataFrame(dic)
print(df)
print(type(df))
print(df["A"])
# Out:
#     A    B
# 0  10  100
# 1  20  200
# 2  30  300
# 3  40  400
# 4  50  500
# <class 'pandas.core.frame.DataFrame'>
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: A, dtype: int64

# %%
dic={"A":[10,20,30,40,50],"B":[100,200,300,400,500],
     1:[1000,2000,3000,4000,5000], "S":[1,2,3,4,5]}
df=pd.DataFrame(dic,columns=["A",1],index=["a","s","d","e","f"],dtype="float")
df
# Out:
#       A       1
# a  10.0  1000.0
# s  20.0  2000.0
# d  30.0  3000.0
# e  40.0  4000.0
# f  50.0  5000.0

# %%
#arithmatic
df=pd.DataFrame({"A":[10,20,30,40,50],"B":[1,2,3,4,5]})
df
# Out:
#     A  B
# 0  10  1
# 1  20  2
# 2  30  3
# 3  40  4
# 4  50  5

# %%
df["C"]=df["A"]+df["B"]
df
# Out:
#     A  B   C
# 0  10  1  11
# 1  20  2  22
# 2  30  3  33
# 3  40  4  44
# 4  50  5  55

# %%
df["C"]=df["A"]-df["B"]
df
# Out:
#     A  B   C
# 0  10  1   9
# 1  20  2  18
# 2  30  3  27
# 3  40  4  36
# 4  50  5  45

# %%
df["C"]=df["A"]**df["B"]
df
# Out:
#     A  B          C
# 0  10  1         10
# 1  20  2        400
# 2  30  3      27000
# 3  40  4    2560000
# 4  50  5  312500000

# %%
df["C"]=df["A"]/df["B"]
df
# Out:
#     A  B     C
# 0  10  1  10.0
# 1  20  2  10.0
# 2  30  3  10.0
# 3  40  4  10.0
# 4  50  5  10.0

# %%
df["C"]=df["A"]//df["B"]
df
# Out:
#     A  B   C
# 0  10  1  10
# 1  20  2  10
# 2  30  3  10
# 3  40  4  10
# 4  50  5  10

# %%
df["Python"]=df["A"]<=30
df["Python_1"]=df["B"]<=3
df
# Out:
#     A  B   C  Python  Python_1  Pythonn
# 0  10  1  10    True      True     True
# 1  20  2  10    True      True     True
# 2  30  3  10    True      True     True
# 3  40  4  10   False     False    False
# 4  50  5  10   False     False    False

# %%
df.insert(1,"python_3",df["A"])

# %%
df
# Out:
#     A  python_3  B   C  Python  Python_1  Pythonn
# 0  10        10  1  10    True      True     True
# 1  20        20  2  10    True      True     True
# 2  30        30  3  10    True      True     True
# 3  40        40  4  10   False     False    False
# 4  50        50  5  10   False     False    False

# %%
df1.insert(2,"python_2",[])
