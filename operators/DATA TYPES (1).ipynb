# %% [markdown]
# # DATA TYPES

# %%
#numeric
# integer
a=10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
a=10.0
print(a)
print(type(a))
# Out:
# 10.0
# <class 'float'>

# %%
#string - ordered sequence of character
# single line denoted by ' ' or " " and multi line by ''' '''
#indexed and immutable
s='' #empty string
print (type(s))
# Out:
# <class 'str'>

# %%
s="decode"
print(s)
print(type(s))
print (s[0])
s[0]="a"
print(s)
# Out:
# decode
# <class 'str'>
# d
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       3 print(type(s))
#       4 print (s[0])
# ----> 5 s[0]="a"
#       6 print(s)
#
# TypeError: 'str' object does not support item assignment

# %%
s=''' hello
welcome
to the city of lakes'''
print(s)
# Out:
#  hello
# welcome
# to the city of lakes

# %%
#list - collection of element 
# it is denoted by with csv.
# indexed
l=[5,2,'v']
print(l)
print(l[2])
print(type(l))
# Out:
# [5, 2, 'v']
# v
# <class 'list'>

# %%
# tuple also contains elements and denoted by ()
t=(10)
print(type(t))
# Out:
# <class 'int'>

# %%
# to make it tuple
t=(10,)
print(type(t))
# Out:
# <class 'tuple'>

# %%
tupple=(10,20,'a')
print(tupple)
# Out:
# (10, 20, 'a')
