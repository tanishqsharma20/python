# %%
#REPLACE
#STROBJ.REPLACE(OLDSTRING,NEWSTRING,{COUNT})
S="WELCOME TO THE CITY"
print(S.replace("WELCOME","bhopal"))
print(S.replace("O","a"))
# Out:
# bhopal TO THE CITY
# WELCaME Ta THE CITY

# %%
#split()
#strobj.split([separator],[maxsplit]
#by default- whiltespace separator, maxsplit= max no of separator
#split always return list of strings
s="welcome to the city of lakes"
print(s.split())
print(s.split(" ",3))
print(s.split(" "))
# Out:
# ['welcome', 'to', 'the', 'city', 'of', 'lakes']
# ['welcome', 'to', 'the', 'city of lakes']
# ['welcome', 'to', 'the', 'city', 'of', 'lakes']

# %%
s="welcome,to,city of lakes"
print(s.split(","))
# Out:
# ['welcome', 'to', 'city of lakes']

# %%
# join
# separator.join(s)
s=["welcome","to","bhopal"]
s1=" ".join(s)
print(s1)
